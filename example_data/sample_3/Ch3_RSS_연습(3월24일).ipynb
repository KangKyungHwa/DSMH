# %% [markdown]
# #RSS(Really Simple Syndication, Rich Site Summary)

# %% [markdown]
# #RSS 활용하기 위해 파서(parser) 이용
# ##파서(parser)란? : 특정한 규칙이나 문법을 가진 데이터를 분석하고, 프로그램이 이해하고 사용할 수 있는 구조로 변환하는 소프트웨어 또는 함수

# %% [markdown]
# ### 한글 기사 검색에서 한글깨짐 방지 위해 폰트 설치

# %%
 # 1. 나눔고딕 폰트 설치
# !sudo apt-get update -qq
# !sudo apt-get install -y fonts-nanum-extra -qq

# 2. 시스템 폰트 캐시 업데이트
# !sudo fc-cache -fv

# 3. Matplotlib 폰트 캐시 삭제
# !rm -rf ~/.cache/matplotlib
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 33 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# ### 네이버 RSS  (참고용)  : 잘 안됨 (실패사례: RSS 기능은 문제가 없으나 자료를 가져오지 못하는 경우도 있음)

# %% [markdown]
# ##  Google 기사 RSS  :성공
# ###
# ### 구글 뉴스 RSS URL: https://news.google.com/rss?hl=ko&gl=KR&ceid=KR:ko
# ### 이 URL은 한국어(hl=ko)로 설정되어 있고, 대한민국(gl=KR) 지역의 기사를 가져오며, 대한민국(ceid=KR:ko)의 엔터티 ID를 사용

# %%
import feedparser
import requests

# Google News RSS 피드 URL을 사용합니다.
url = "https://news.google.com/rss?hl=ko&gl=KR&ceid=KR:ko"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/121.0.0.0 Safari/537.36",
    "Accept": "application/rss+xml, application/xml;q=0.9,*/*;q=0.8"
}

try:
    response = requests.get(url, headers=headers)
    response.raise_for_status() # HTTP 오류가 발생하면 예외를 발생시킵니다.
    feed = feedparser.parse(response.text) # 가져온 텍스트 내용을 파싱합니다.

    if not feed.feed:
        print("오류: RSS 피드 메타데이터를 찾을 수 없습니다.")
    else:
        print("피드 제목:", feed.feed.get('title', '제목 없음'))

    if not feed.entries:
        print("오류: 피드에서 기사를 찾을 수 없습니다.")
    else:
        print(f"파싱된 뉴스 기사의 개수: {len(feed.entries)}")
        print("\n--- 주요 뉴스 기사 제목 (상위 5개) ---")
        for i, entry in enumerate(feed.entries[:100]):
            print(f"{i+1}. {entry.get('title', '제목 없음')}")

except requests.exceptions.RequestException as e:
    print(f"요청 중 오류 발생: {e}")
except Exception as e:
    print(f"피드 파싱 중 오류 발생: {e}")
# Out:
# 피드 제목: 주요 뉴스 - Google 뉴스
# 파싱된 뉴스 기사의 개수: 32
#
# --- 주요 뉴스 기사 제목 (상위 5개) ---
# 1. 트럼프 “오늘 이란과 전화로 협의할듯…양측 합의 성사 원해” - 조선일보
# 2. 영덕 풍력발전기 화재로 3명 숨져…파손 사고 49일 만에 또 사고 - 한겨레
# 3. 장동혁, ‘이정현표 공천 파동’에 “공관위 결정 존중…희생도 필요” - 조선일보
# 4. 조현, 이란 외교장관과 통화…고립된 韓선박의 안전한 통과 요청 - 동아일보
# 5. 불법 증축 “눈으로 확인 안한다”…참사 배경엔 정부 감독 기관들 - 한겨레
# 6. BTS노믹스로 증명된 'K컬처의 힘'…3000만 관광 시대 앞당긴다 - 대한민국 정책브리핑
# 7. 고민정, ‘친문 저격’ 송영길에 “스스로 서울 사람이라 하더니 이번엔 인천이냐” - 경향신문
# 8. 김부겸 "당이 대구발전 비전 먼저 보여야…출마 여부 이달 결론" - 연합뉴스
# 9. 이 대통령 “0.1% 구멍도 안 돼”…다주택 공직자 부동산 정책서 배제 - 한겨레
# 10. 종합특검, 대검·중앙지검 압수수색…김건희 수사 무마 의혹 - 연합뉴스TV
# 11. “이스라엘에서 산다는 건 러시안 룰렛”…방공망 뚫린 이스라엘 불안감 확산 - 경향신문
# 12. 호르무즈 봉쇄 장기화에 지친 나토, 군사개입 카드 꺼내나 - 한국경제
# 13. 종량제봉투 사재기 대란…나프타 공급망 ‘직격탄’ - 문화일보
# 14. 기름값 2주마다 계단식 상승 전망…“최고가격제 효과 크지만 제한적 활용을” - 한겨레
# 15. [속보]‘검은 월요일’에 코스피 6.5% 급락 마감, 금값 8% 폭락 - 경향신문
# 16. 나프타 쇼크 현실화…정부 ‘수출물량→내수’ 전환 추진(종합) - 국제신문
# 17. [오늘의 스팀] "장르 재미 훼손" 슬더스 2 패치에 평가 급락 - 게임메카
# 18. ASUS, 14형 게이밍 노트북 ‘TUF A14’ 사전예약 돌입…문라이트 화이트 첫선 - 뉴스탭
# 19. 대원씨티에스, B850M Challenger WiFi 7 White 메인보드 출시 - 아이러브PC방
# 20. 캡콤 "생성형 AI가 만든 결과물, 게임에 넣지 않겠다" - 인벤
# 21. 실언, 폭로 고소 다음은.."경호팀 섭외" 신화 김동완, '무료 공연' 강행 초강수 [공식] - ASIA ARTIST AWARDS 2025
# 22. ‘왕사남’ 장항준, 60억 성과급 날렸나…“러닝 개런티 없어” 탄식 - 조선일보
# 23. 전지현 시母, BTS 영어 저격? "마음 놓고 덕질도 못하냐" 일갈 - starnewskorea.com
# 24. 정이랑, 남편과 결혼 15년차에도 달달 "전지현이 무슨 궁합 얘기" [짠한형] - ASIA ARTIST AWARDS 2025
# 25. 제주SK FC 2005년생 인정? 어 조인정! 환상의 K리그1 데뷔골로 눈도장 '쾅' - 뉴스N제주
# 26. '무패패무무패패패패패무패' 토트넘, 소방수도 재앙이네...英 BBC 다음 후보 3명 공개 "생존 위해 3번째 감독 고를 수도" - 조선일보
# 27. MLB 다저스 김혜성, 시범경기 타율 0.407에도 마이너리그행 - 경기일보
# 28. JTBC, 지상파 3사에 "월드컵 중계권료 절반씩 부담하자" 제안 - v.daum.net
# 29. 조부모·부모·손자 손녀 3대가 맞는 프리베나20, 화이자 인식 높이기 나서 - 팜뉴스
# 30. 전세계 2억명 고통…“스트레스 받지 마, OOO 더 심해져”, 사실일까? - 농민신문
# 31. 동아시아인, 키 클수록 ‘이 병’ 걸릴 위험 높다고? - 코메디닷컴
# 32. 우울증 겪는 환자 뇌 들여다보니 "세포끼리 소통 끊겼다" - 히트뉴스

# %% [markdown]
# ## 불러온 뉴스 자료들을 리스트에 저장하기

# %%
import pandas as pd

# DataFrame에 저장할 데이터를 담을 리스트를 생성합니다.
news_data = []

# feed.entries를 반복하여 각 기사의 정보를 추출합니다.
for entry in feed.entries:
    title = entry.get('title', '제목 없음')
    link = entry.get('link', '링크 없음')
    published = entry.get('published', '발행일 정보 없음')
    summary = entry.get('summary', '요약 정보 없음')

    news_data.append({
        '제목': title,
        '링크': link,
        '발행일': published,
        '요약': summary
    })

# 추출된 데이터를 사용하여 pandas DataFrame을 생성합니다.
df_news = pd.DataFrame(news_data)

# 생성된 DataFrame의 첫 5행을 출력하여 확인합니다.
print("--- 뉴스 기사 DataFrame (상위 5개) ---")
display(df_news.head())

# DataFrame의 총 행 수를 출력합니다.
print(f"\nDataFrame에 저장된 총 뉴스 기사 수: {len(df_news)}개")
# Out:
# --- 뉴스 기사 DataFrame (상위 5개) ---
#                                              제목  \
# 0      트럼프 “오늘 이란과 전화로 협의할듯…양측 합의 성사 원해” - 조선일보
# 1    영덕 풍력발전기 화재로 3명 숨져…파손 사고 49일 만에 또 사고 - 한겨레
# 2  장동혁, ‘이정현표 공천 파동’에 “공관위 결정 존중…희생도 필요” - 조선일보
# 3     조현, 이란 외교장관과 통화…고립된 韓선박의 안전한 통과 요청 - 동아일보
# 4     불법 증축 “눈으로 확인 안한다”…참사 배경엔 정부 감독 기관들 - 한겨레
#
#                                                   링크  \
# 0  https://news.google.com/rss/articles/CBMingFBV...
# 1  https://news.google.com/rss/articles/CBMiZEFVX...
# 2  https://news.google.com/rss/articles/CBMikAFBV...
# 3  https://news.google.com/rss/articles/CBMid0FVX...
# 4  https://news.google.com/rss/articles/CBMiakFVX...
#
#                              발행일  \
# 0  Mon, 23 Mar 2026 14:37:30 GMT
# 1  Mon, 23 Mar 2026 13:14:00 GMT
# 2  Mon, 23 Mar 2026 07:39:00 GMT
# 3  Mon, 23 Mar 2026 12:50:00 GMT
# 4  Mon, 23 Mar 2026 14:09:00 GMT
#
#                                                   요약
# 0  <ol><li><a href="https://news.google.com/rss/a...
# 1  <ol><li><a href="https://news.google.com/rss/a...
# 2  <ol><li><a href="https://news.google.com/rss/a...
# 3  <ol><li><a href="https://news.google.com/rss/a...
# 4  <ol><li><a href="https://news.google.com/rss/a...
# DataFrame에 저장된 총 뉴스 기사 수: 32개

# %% [markdown]
# ## df_news 데이터프레임에 저장되어진 뉴스기사들을  csv 파일로 저장하기

# %%
#한글이 저장될 때 깨지지 않도록 utf-8 로 인코딩해서 저장
df_news.to_csv('google_news_articles.csv', index=False, encoding='utf-8')

print("DataFrame이 'google_news_articles.csv' 파일로 성공적으로 저장되었습니다.")
print("왼쪽 파일 탐색기에서 파일을 확인할 수 있습니다.")
# Out:
# DataFrame이 'google_news_articles.csv' 파일로 성공적으로 저장되었습니다.
# 왼쪽 파일 탐색기에서 파일을 확인할 수 있습니다.

# %% [markdown]
# ## Google 기사 파일 내용 확인하기

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

data = pd.read_csv('/content/google_news_articles.csv')
print("파일이 성공적으로 로드되었습니다.")
print(data.head(100))

# %% [markdown]
# ## 연습 :  카카오기술블로그 RSS

# %%
import feedparser
import requests

# 카카오 기술블로그 RSS 피드 URL을 사용합니다.
url = "https://tech.kakao.com/feed"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/121.0.0.0 Safari/537.36",
    "Accept": "application/rss+xml, application/xml;q=0.9,*/*;q=0.8"
}

try:
    response = requests.get(url, headers=headers)
    response.raise_for_status() # HTTP 오류가 발생하면 예외를 발생시킵니다.
    feed = feedparser.parse(response.text) # 가져온 텍스트 내용을 파싱합니다.

    if not feed.feed:
        print("오류: RSS 피드 메타데이터를 찾을 수 없습니다.")
    else:
        print("피드 제목:", feed.feed.get('title', '제목 없음'))

    if not feed.entries:
        print("오류: 피드에서 기사를 찾을 수 없습니다.")
    else:
        print(f"파싱된 뉴스 기사의 개수: {len(feed.entries)}")
        print("\n--- 주요 뉴스 기사 제목 (상위 5개) ---")
        for i, entry in enumerate(feed.entries[:100]):
            print(f"{i+1}. {entry.get('title', '제목 없음')}")

except requests.exceptions.RequestException as e:
    print(f"요청 중 오류 발생: {e}")
except Exception as e:
    print(f"피드 파싱 중 오류 발생: {e}")
# Out:
# 피드 제목: tech.kakao.com
# 파싱된 뉴스 기사의 개수: 10
#
# --- 주요 뉴스 기사 제목 (상위 5개) ---
# 1. 수억 건의 보안 신호 속 진짜 위협 찾기 — AI로 보안 모니터링의 패러다임을 바꾸다
# 2. 학생에서 개발자로: 로또 구현부터 레거시 개선까지, 서버의 흐름을 배우다
# 3. 학생에서 개발자로: DB, 보안부터 AI까지, 정답보다 합리적인 선택을 배우다
# 4. 한국 문화 이해부터 화면 조작까지: Kanana-V 기능 확장의 모든 것
# 5. 2026 카카오그룹 신입크루 공채 코딩테스트 2차 문제해설
# 6. 2026 카카오그룹 신입크루 공채 코딩테스트 1차 문제해설
# 7. Kanana-o 신규 모델 및 API 베타 서비스를 공개합니다.
# 8. 잃어버린 리포트를 찾아서: 카카오 메시징 시스템의 경쟁 조건 문제와 안티 패턴 제거 과정
# 9. 카카오 AI 앰배서더 ‘KANANA 429 앰배서더’를 신규 모집합니다.
# 10. Kanana-2 개발기 (2): 개선된 post-training recipe를 중심으로
