# %% [markdown]
# #**Ch2.4 Pandas 개요(2)**

# %% [markdown]
# #**2.4.2**.캘리포니아 주택 데이터프레임 훑어보기

# %% [markdown]
# ###(1) 데이터 불러오기

# %%
# !git clone 'https://'github.com/KangKyungHwa/DSMH/''
# Out:
# Cloning into ''''...
# fatal: protocol ''https' is not supported

# %%
import pandas as pd

housing_df= pd.read_csv('C:/DSMH/1_Class/3월24일/california_housing_train.csv')

print('housing_df 변수 type : ', type(housing_df))
print(housing_df)

# %%
import pandas as pd

file_path_csv = 'c:/DSMH/1_Class/3월24일/smartphone_usage_time.csv'
smartphone_df = pd.read_csv(file_path_csv)

print('smartphone_df 변수 type : ', type(smartphone_df))
display(smartphone_df.head())
# Out:
# smartphone_df 변수 type :  <class 'pandas.core.frame.DataFrame'>
#    27
# 0  40
# 1  38
# 2  35
# 3  52
# 4  53

# %% [markdown]
# ###(2) shape, head() 함수

# %%
# shape : 데이터프레임의 행과 열 정보를 튜플형태로 반환
# head(): 데이터 프레임의 6개(지정해야 함)
print('DataFrame 크기 : ', housing_df.shape, "\n\n")
print(housing_df.head(6))

# %% [markdown]
# ###(3) info() 함수

# %%
#데이터 프레임의 Non-NUll 데이터 개수 확인할  때 사용

print(housing_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB
# None

# %% [markdown]
# ###(4) describe() 함수

# %%
#데이터 프레임의 기초 통계 정보 조회 가능(컬럼별 숫자형 데이터의 개수, 평균값, 표준편차, 최솟값, 사분위수값, 최대값)

print(housing_df.describe())
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
#  ### (5)  head() 함수

# %%
#houging_median_age 상위 기본 5개 data 확인  (더 많은 데이터를 보고 싶을 때 숫자를 넣어준다)

housing_median_age = housing_df['housing_median_age']
print(housing_median_age.head())
# Out:
# 0    15.0
# 1    19.0
# 2    17.0
# 3    14.0
# 4    20.0
# Name: housing_median_age, dtype: float64

# %% [markdown]
# ###(6) value_count 함수

# %%
#houging_median_age column의 데이터 분포도를 알 수 있다.
#데이터 건수가 많은 순서로 정렬되어 값 반환

value_counts = housing_median_age.value_counts()
print(value_counts)
# Out:
# housing_median_age
# 52.0    1052
# 36.0     715
# 35.0     692
# 16.0     635
# 17.0     576
# 34.0     567
# 33.0     513
# 26.0     503
# 18.0     478
# 25.0     461
# 32.0     458
# 37.0     437
# 15.0     416
# 19.0     412
# 28.0     400
# 27.0     397
# 24.0     389
# 31.0     384
# 30.0     384
# 20.0     383
# 23.0     382
# 29.0     374
# 21.0     373
# 14.0     347
# 22.0     323
# 38.0     318
# 42.0     308
# 39.0     302
# 44.0     296
# 43.0     286
# 13.0     249
# 40.0     249
# 45.0     235
# 41.0     232
# 10.0     226
# 11.0     208
# 5.0      199
# 46.0     196
# 12.0     192
# 8.0      178
# 47.0     175
# 9.0      172
# 4.0      161
# 7.0      151
# 48.0     135
# 6.0      129
# 50.0     112
# 49.0     111
# 2.0       49
# 3.0       46
# 51.0      32
# 1.0        2
# Name: count, dtype: int64

# %% [markdown]
# ###(7) 데이터프레임 컬럼 생성과 수정

# %%
#  Age_0 이라는 컬럼 생성한 후 기본값으로 0을 할당한다
housing_df['Age_0'] = 0

print(housing_df.head(3))
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
#
#    population  households  median_income  median_house_value  Age_0
# 0      1015.0       472.0         1.4936             66900.0      0
# 1      1129.0       463.0         1.8200             80100.0      0
# 2       333.0       117.0         1.6509             85700.0      0
