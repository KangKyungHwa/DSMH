# %% [markdown]
# # **chapter 2.**

# %% [markdown]
# ##2.3  데이터 시각화와 요약

# %% [markdown]
# ### python 라이브러리 matplotlib 와 Seaborn 배우기

# %% [markdown]
# ###github의 저장소 데이터를 사용하기 위해 연결

# %%
# !git clone 'https://'github.com/KangKyungHwa/DSMH/''
# Out:
# fatal: destination path 'DSMH' already exists and is not an empty directory.

# %% [markdown]
# ###font 설치  :한글이 깨지는 현상 방지 목적

# %%
# 1. 나눔고딕 폰트 설치
# !sudo apt-get update -qq
# !sudo apt-get install -y fonts-nanum-extra -qq

# 2. 시스템 폰트 캐시 업데이트
# !sudo fc-cache -fv

# 3. Matplotlib 폰트 캐시 삭제
# !rm -rf ~/.cache/matplotlib

# %% [markdown]
# ###Google colab에서 한글이 깨지는 현상 방지를 위해 나눔고딕 폰트 설치후
# ###상위 메뉴에서   (런타임)->(세션 다시시작) 꼭 실행하기!!!!

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "NanumGothic"  # 한글폰트가 제대로 적용되었는지 확인

# %%
import matplotlib.pyplot as plt

print("현재 Matplotlib 폰트 설정:", plt.rcParams['font.family']) #현재 설치된 폰트 확인
# Out:
# 현재 Matplotlib 폰트 설정: ['NanumGothic']

# %% [markdown]
# ###Example 2.3.1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 엑셀 파일 불러오기  참고
data = pd.DataFrame(pd.read_excel('DSMH/example_data/sample_2/highschool_samples.xlsx'))
#data = pd.DataFrame(pd.read_excel('/content/DSMH/example_data/sample_2/highschool_samples.xlsx'))



plt.hist(data.height, label='bins=10', bins=10) #막대수 10개로 하고 레이블 작성
#plt.legend()
plt.show()

# %% [markdown]
# ###Example 2.3.2

# %%
from matplotlib import pyplot as plt
import matplotlib.font_manager as fm

# Matplotlib 폰트 설정 (이전에 설치된 NanumGothic 사용)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지

x=[ '보조출연.방청', '방문.학습지 교사', '컴퓨터.정보통신', '교육.강사 기타', '요가.필라테스 강사']
y=[29874, 23551, 20812, 19930, 19766]

x1=[ '커피전문점',  '캐셔.카운터', '베이커리.도넛.떡', '아이스크림.디저트', '편의점']
y1=[9411, 9371, 9354, 9317, 9268]

plt.bar(x, y)                      # x축과 y축의 데이터
plt.title('아르바이트 상위시급')   # 제목 표시
plt.xticks(rotation=20)            #x축 레이블 회전
plt.show()

plt.barh(x1, y1)
plt.title('아르바이트 하위시급')
plt.show()

# %% [markdown]
# ###Example 2.3.3

# %%
from matplotlib import pyplot as plt

# Matplotlib 폰트 설정 (이전에 설치된 NanumGothic 사용)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지

ratio = [46.0, 30.0, 13.6, 8.7, 1.7]    # 퍼센트 비율 (전체 합은 100)
labels = ['visit_hometown', 'rest at home', 'Domestic travel', 'Overseas travel', 'etc']  #레이블
plt.pie(ratio, labels=labels, autopct='%.1f%%')  # 퍼센트의 표시 방법
plt.show()

# %% [markdown]
# ###Example 2.3.4

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Matplotlib 폰트 설정 (이전에 설치된 NanumGothic 사용)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지

#data = pd.DataFrame(pd.read_excel('DSMH/example_data/sample_2/gasoline_milk_price.xlsx'))
data = pd.DataFrame(pd.read_excel('/content/DSMH/example_data/sample_2/gasoline_milk_price.xlsx'))
x = data.year
y1 = data.gasoline
y2 =data.milk

plt.plot(x, y1, linestyle='solid', label='gasoline')  # x와 y1 그래프 작성
plt.plot(x, y2, linestyle='dashed', label='milk')  # x와 y2 그래프 작성

plt.legend(loc='best', ncol=2)                # 레이블 표시 방법
plt.title('change of price')
plt.show()

# %% [markdown]
# ###Example 2.3.5

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
data = pd.read_csv('DSMH/example_data/sample_2/smartphone_usage_time.csv')

print('median = ', np.median(data))     #중앙값
print('min = ', np.min(data),'\n')       #최솟값

plt.boxplot(data, vert=False)           # 수평의 상자도형 (False의 F는 대문자로)
plt.show()
# Out:
# median =  39.0
# min =  15

# %% [markdown]
# ###Example 2.3.6

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Matplotlib 폰트 설정 (이전에 설치된 NanumGothic 사용)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지

data = pd.DataFrame(pd.read_excel('DSMH/example_data/sample_2/elm_students_tall_weight.xlsx'))

plt.scatter(data.height, data.weight) # [그림 2-46]의 열 제목을 그대로 사용
plt.xlabel('height')
plt.ylabel('weight')
plt.show()

# %% [markdown]
# ###Example 2.3.7

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')      # 라이브러리 sns에서 iris 데이터 불러오기
iris.head()

sns.pairplot(iris, diag_kind='hist')    # 산점도 행렬
plt.show()

# %% [markdown]
# ###Example 2.3.8

# %%
import numpy as np
import pandas as pd
from scipy import stats

x = pd.read_excel("DSMH/example_data/sample_2/elm_students_tall_weight.xlsx")

# 평균 계산
print('mean = ', np.average(x), '\n')

# 중앙값 계산
print('median =', np.median(x),'\n')

# 최빈값 계산
print('mode =', stats.mode(x))
# Out:
# mean =  78.17205882352941
#
# median = 86.7
#
# mode = ModeResult(mode=array([115.2,  21.6]), count=array([2, 2]))

# %% [markdown]
# ###Example 2.3.9

# %%
import numpy as np
import pandas as pd

data = pd.DataFrame(pd.read_excel("DSMH/example_data/sample_2/highschool_samples.xlsx"))

print('키의 범위 range : ', np.max(data.height)-np.min(data.height))
print('몸무게의 범위 range : ', np.max(data.weight)-np.min(data.weight),'\n')

print('키의 분산 variance : ', np.var(data.height))
print('몸무게의 분산 variance : ', np.var(data.weight),'\n')

print('키의 표준편차standard deviation : ', np.std(data.height))
print('몸무게의 표준편차standard deviation : ', np.std(data.weight))
# Out:
# 키의 범위 range :  34.30000000000001
# 몸무게의 범위 range :  87.80000000000001
#
# 키의 분산 variance :  38.83150063999999
# 몸무게의 분산 variance :  167.31795135999997
#
# 키의 표준편차standard deviation :  6.231492649438013
# 몸무게의 표준편차standard deviation :  12.935144040945195

# %% [markdown]
# ###Example 2.3.10

# %%
import pandas as pd
from scipy import stats

data = pd.DataFrame(pd.read_excel("DSMH/example_data/sample_2/highschool_samples.xlsx"))

print(data.describe())

print(stats.describe(data))
# Out:
#            height      weight
# count  500.000000  500.000000
# mean   173.304400   68.719200
# std      6.237734   12.948099
# min    155.700000   41.600000
# 25%    169.100000   59.000000
# 50%    173.500000   67.000000
# 75%    177.325000   75.525000
# max    190.000000  129.400000
# DescribeResult(nobs=np.int64(500), minmax=(array([155.7,  41.6]), array([190. , 129.4])), mean=array([173.3044,  68.7192]), variance=array([ 38.90931928, 167.65325788]), skewness=array([0.03447494, 0.97903753]), kurtosis=array([-0.11000672,  1.65997625]))
